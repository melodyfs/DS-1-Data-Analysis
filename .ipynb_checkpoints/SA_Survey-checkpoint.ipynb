# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import glob, os
# %matplotlib inline

# %% [markdown]
# <h1>2016</h1>

# %% [markdown]
# <h2>Week 1-7</h2>

# %%
files = glob.glob('datasets/2016/Anon Week ? Feedback - *.csv')

dfs_2016 = [pd.read_csv(fp).assign(Week=os.path.basename(fp[24]), 
                                   Location=os.path.basename(fp[36:-4])) for fp in files]
df_2016 = pd.concat(dfs_2016, ignore_index = True)
df_2016.columns = ['Schedule Pacing', 
                   'Schedule Pacing2', 
                   'Rating', 
                   'Location', 
                   'Timestamp', 
                   'Unnamed:0', 
                   'Week', 
                   'Track']

pace = df_2016['Schedule Pacing'].fillna(df_2016['Schedule Pacing2'])
year = [ 2016 for i in range(len(df_2016))]
df_2016['Schedule Pacing'] = pace
df_2016['Year'] = year


# convert rating to NPS segments
ratings_16 = df_2016['Rating']
new_ratings_16 = np.array([])

for n in ratings_16:
    if not n == "nan" and not n == "#ERROR!" and not n == "#REF!":
        if float(n) > 4:
            new_ratings_16 = np.append(new_ratings_16, "Promoter")
        elif float(n) > 3:
            new_ratings_16 = np.append(new_ratings_16, "Passive")
        else:
            new_ratings_16 = np.append(new_ratings_16, "Detractor")
    else:
        new_ratings_16 = np.append(new_ratings_16, "NaN")

rating_df_16 = pd.DataFrame(new_ratings_16)
df_2016['Rating'] = rating_df_16

clean_df_2016 = df_2016.drop(['Unnamed:0','Schedule Pacing2'], axis=1)
clean_df_2016
# Out:
#     Schedule Pacing     Rating Location          Timestamp Week  Track  Year
# 0                 4  Detractor       LA      6/23/16 15:55    1    NaN  2016
# 1                 4    Passive       LA      6/23/16 16:14    1    NaN  2016
# 2                 4    Passive       LA       6/24/16 0:18    1    NaN  2016
# 3                 4    Passive       LA       6/24/16 6:59    1    NaN  2016
# 4                 5    Passive       LA       6/24/16 9:40    1    NaN  2016
# 5                 4   Promoter       LA      6/23/16 22:07    1    NaN  2016
# 6                 3   Promoter       LA       6/24/16 9:34    1    NaN  2016
# 7                 5  Detractor       NY  6/24/2016 7:03:34    1  Games  2016
# 8                 3  Detractor       NY  6/24/2016 7:10:22    1  Games  2016
# 9                 3  Detractor       NY  6/24/2016 7:03:41    1   Apps  2016
# 10                3    Passive       NY  6/24/2016 7:04:59    1  Intro  2016
# 11                4    Passive       NY  6/24/2016 7:07:02    1  Intro  2016
# 12                4    Passive       NY  6/24/2016 7:08:41    1  Intro  2016
# 13                4    Passive       NY  6/24/2016 7:09:30    1  Intro  2016
# 14                4    Passive       NY  6/24/2016 7:01:03    1  Games  2016
# 15                4    Passive       NY  6/24/2016 7:02:43    1  Games  2016
# 16                3    Passive       NY  6/24/2016 7:03:48    1  Games  2016
# 17                3    Passive       NY  6/24/2016 7:06:04    1  Games  2016
# 18                4    Passive       NY  6/24/2016 7:06:24    1  Games  2016
# 19                4    Passive       NY  6/24/2016 7:01:19    1   Apps  2016
# 20                4    Passive       NY  6/24/2016 7:01:29    1   Apps  2016
# 21                4    Passive       NY  6/24/2016 7:02:20    1   Apps  2016
# 22                3    Passive       NY  6/24/2016 7:03:24    1   Apps  2016
        promos = df_week[df_week["Rating"] == "Promoter"].size
        detracts = df_week[df_week["Rating"] == "Detractor"].size
        passives = df_week[df_week["Rating"] == "Passive"].size
        nps = (promos - detracts) / (promos + detracts + passives) * 100
        nps_scores = np.append(nps_scores, nps)
    return nps_scores

# %% [markdown]
# <h2>Week 8</h2>

# %%
df_16_w8 = pd.read_csv('datasets/2016/Week 8 Feedback (2016, incomplete) - results.csv')
df_16_w8_renamed = df_16_w8.rename(columns={'How likely is it that you would recommend the Make School Summer Academy to a friend?': 'Rating',
                                            'location': 'Location',
                                            'track': 'Track'})
year = [ 2016 for i in range(len(df_16_w8_renamed))]
week = [ 8 for i in range(len(df_16_w8_renamed))]
df_16_w8_renamed['Year'] = year
df_16_w8_renamed['Week'] = week

df_16_w8_renamed['Track'] = df_16_w8_renamed['Track'].map({'summerApps': 'Apps',
                                                  'summerIntro': 'Intro',
                                                  'summerGames': 'Games',
                                                  'summerVR': 'VR',
                                                  'summerApps (4-week)': 'Apps (4-Week)'})
''
rating_w8_df = pd.DataFrame(convert_ratings(df_16_w8_renamed, 'Rating'))
df_16_w8_renamed['Rating'] = rating_w8_df
clean_16_w8 = df_16_w8_renamed.drop(['#','Network ID'], axis=1)

clean_16_w8
# Out:
#        Rating       Location          Track Start Date (UTC)  \
# 0    Promoter       New York           Apps      9/7/16 1:03
# 1    Promoter  San Francisco          Intro      9/7/16 1:03
# 2    Promoter       New York          Intro      9/7/16 1:03
# 3    Promoter      Sunnyvale  Apps (4-Week)      9/7/16 1:04
# 4   Detractor  San Francisco          Intro      9/7/16 1:04
# 5    Promoter  San Francisco           Apps      9/7/16 1:09
# 6     Passive  San Francisco           Apps      9/7/16 1:04
# 7   Detractor       New York          Games      9/7/16 1:14
# 8   Detractor      Singapore           Apps      9/7/16 1:16
# 9    Promoter       New York          Games      9/7/16 1:22
# 10   Promoter      Sunnyvale          Games      9/7/16 1:28
# 11   Promoter  San Francisco             VR      9/7/16 1:22
# 12    Passive  San Francisco          Intro      9/7/16 1:30
# 13    Passive      Sunnyvale           Apps      9/7/16 1:47
# 14    Passive    Los Angeles          Games      9/7/16 1:34
# 15   Promoter  San Francisco           Apps      9/7/16 2:28
# 16   Promoter      Sunnyvale          Games      9/7/16 2:39
# 17   Promoter       New York          Games      9/7/16 2:39
# 18    Passive      Singapore           Apps      9/7/16 2:47
# 19   Promoter  San Francisco          Intro      9/7/16 2:56
# 20   Promoter  San Francisco           Apps      9/7/16 2:58
# 21   Promoter      Sunnyvale          Games      9/7/16 2:59
# 22  Detractor       New York          Intro      9/7/16 3:05
# 23   Promoter  San Francisco          Games      9/7/16 3:22
# 24   Promoter      Sunnyvale          Games      9/7/16 3:15
# 25   Promoter      Sunnyvale           Apps      9/7/16 3:41
# 26   Promoter  San Francisco          Intro      9/7/16 4:04
# 27   Promoter      Sunnyvale           Apps      9/7/16 4:07
# 28    Passive      Sunnyvale          Games      9/7/16 4:20
# 29   Promoter  San Francisco          Games      9/7/16 5:41
# ..        ...            ...            ...              ...
# 39      9/7/16 14:54  2016     8
# 40      9/7/16 15:58  2016     8
# 41      9/7/16 17:21  2016     8
# 42      9/7/16 19:25  2016     8
# 43      9/7/16 19:26  2016     8
# 44      9/7/16 19:40  2016     8
# 45      9/7/16 19:57  2016     8
# 46       9/8/16 0:00  2016     8
# 47       9/8/16 0:58  2016     8
# 48       9/8/16 1:59  2016     8
# 49       9/8/16 6:04  2016     8
# 50      9/8/16 14:27  2016     8
# 51      9/8/16 22:06  2016     8
# 52      9/8/16 22:20  2016     8
# 53      9/8/16 23:07  2016     8
# 54      9/8/16 23:11  2016     8
# 55       9/9/16 1:42  2016     8
# 56       9/9/16 4:25  2016     8
# 57      9/9/16 11:09  2016     8
# 58      9/9/16 13:28  2016     8
# 59     9/10/16 22:30  2016     8
# 60      9/12/16 0:13  2016     8
# 61      9/13/16 4:42  2016     8
# 62     9/13/16 20:13  2016     8
# 63     9/14/16 12:10  2016     8
# 64     9/26/16 16:34  2016     8
#
# [65 rows x 7 columns]

# %%
def get_nps_2016_w8():
    nps_scores = 0
    promos = clean_16_w8[clean_16_w8["Rating"] == "Promoter"].size
    detracts = clean_16_w8[clean_16_w8["Rating"] == "Detractor"].size
    passives = clean_16_w8[clean_16_w8["Rating"] == "Passive"].size
    nps = (promos - detracts) / (promos + detracts + passives) * 100
    nps_scores = nps
    return nps_scores
nps_16_w8 = get_nps_2016_w8()
nps_16_w8
# Out:
# 55.384615384615387

# %% [markdown]
# <h2>Complete 2016 Data (Week 1-8)</h2>

# %%
frames = [clean_df_2016, clean_16_w8]
complete_2016_df = pd.concat(frames)
complete_2016_df['Location'] = complete_2016_df['Location'].replace({'Los Angeles': ' LA',
                                                                     'New York': ' NY',
                                                                    'Singapore': ' SG',
                                                                    'Sunnyvale': ' SV',
                                                                    'San Francisco': ' SF',
                                                                    ' Singapore': ' SG'})

# %%
complete_2016_df
# Out:
#    Location     Rating Schedule Pacing Start Date (UTC) Submit Date (UTC)  \
# 0        LA  Detractor               4              NaN               NaN
# 1        LA    Passive               4              NaN               NaN
# 2        LA    Passive               4              NaN               NaN
# 3        LA    Passive               4              NaN               NaN
# 4        LA    Passive               5              NaN               NaN
# 5        LA   Promoter               4              NaN               NaN
# 6        LA   Promoter               3              NaN               NaN
# 7        NY  Detractor               5              NaN               NaN
# 8        NY  Detractor               3              NaN               NaN
# 9        NY  Detractor               3              NaN               NaN
# 10       NY    Passive               3              NaN               NaN
# 11       NY    Passive               4              NaN               NaN
# 12       NY    Passive               4              NaN               NaN
# 13       NY    Passive               4              NaN               NaN
# 14       NY    Passive               4              NaN               NaN
# 15       NY    Passive               4              NaN               NaN
# 16       NY    Passive               3              NaN               NaN
# 17       NY    Passive               3              NaN               NaN
# 18       NY    Passive               4              NaN               NaN
# 19       NY    Passive               4              NaN               NaN
# 20       NY    Passive               4              NaN               NaN
# 21       NY    Passive               4              NaN               NaN
# 22       NY    Passive               3              NaN               NaN
# 23       NY    Passive               4              NaN               NaN
# 24       NY    Passive               2              NaN               NaN
# 25       NY    Passive               3              NaN               NaN
# 14  6/24/2016 7:01:03          Games    1  2016
# 15  6/24/2016 7:02:43          Games    1  2016
# 16  6/24/2016 7:03:48          Games    1  2016
# 17  6/24/2016 7:06:04          Games    1  2016
# 18  6/24/2016 7:06:24          Games    1  2016
# 19  6/24/2016 7:01:19           Apps    1  2016
# 20  6/24/2016 7:01:29           Apps    1  2016
# 21  6/24/2016 7:02:20           Apps    1  2016
# 22  6/24/2016 7:03:24           Apps    1  2016
# 23  6/24/2016 7:03:25           Apps    1  2016
# 24  6/24/2016 7:03:58           Apps    1  2016
# 25  6/24/2016 7:06:59           Apps    1  2016
# 26  6/24/2016 7:07:06           Apps    1  2016
# 27  6/24/2016 7:08:37           Apps    1  2016
# 28  6/24/2016 7:08:51           Apps    1  2016
# 29  6/24/2016 7:01:55          Intro    1  2016
# ..                ...            ...  ...   ...
# 35                NaN           Apps    8  2016
# 36                NaN           Apps    8  2016
# 37                NaN          Intro    8  2016
# 38                NaN  Apps (4-Week)    8  2016
# 39                NaN           Apps    8  2016
# 40                NaN           Apps    8  2016
# 41                NaN           Apps    8  2016
# 42                NaN             VR    8  2016
# 43                NaN  Apps (4-Week)    8  2016
# 44                NaN           Apps    8  2016
# 45                NaN          Games    8  2016
# 46                NaN          Intro    8  2016
# 47                NaN           Apps    8  2016
# 48                NaN          Games    8  2016
# 49                NaN           Apps    8  2016
# 50                NaN            NaN    8  2016
# 51                NaN          Games    8  2016
# 52                NaN           Apps    8  2016
# 53                NaN           Apps    8  2016
# 54                NaN           Apps    8  2016
# 55                NaN          Intro    8  2016
# 56                NaN          Intro    8  2016
# 57                NaN           Apps    8  2016
# 58                NaN          Games    8  2016
# 59                NaN          Games    8  2016
# 60                NaN           Apps    8  2016
# 61                NaN             VR    8  2016
# 62                NaN            NaN    8  2016
# 63                NaN          Intro    8  2016
# 64                NaN          Games    8  2016
#
# [992 rows x 9 columns]

# %%
nps_2016 = get_nps_2016()
nps_2016 = np.append(nps_2016, get_nps_2016_w8())
complete_data_2016 = {'Week': [i for i in range(1,9)], 'NPS': nps_2016}
nps_df_2016 = pd.DataFrame(complete_data_2016)
nps_df_2016.plot(x="Week", y="NPS", title="NPS of Each Week in 2016", figsize=(8, 5))
plt.xlim(1,8)
plt.ylim(-100,100)
# Out:
# (-100, 100)

# %% [markdown]
# 2. Relationship between track and pace
# 3. Relationship between rating and location
# 4. Same track but different location -> Variation in Rating

# %%
def filter_data_df(_df, attr, value=None):
    if value is None:
        result = _df[attr]
    result = _df[(_df[attr] == value)]
    return result

# %% [markdown]
# ### 1. Promoters from each track

# %%
apps = filter_data_df(complete_2016_df, 'Track', 'Apps')
games = filter_data_df(complete_2016_df, 'Track', 'Games')
vr = filter_data_df(complete_2016_df, 'Track', 'VR')
intro = filter_data_df(complete_2016_df, 'Track', 'Intro')
apps_4w = filter_data_df(complete_2016_df, 'Track', 'Apps (4-Week)')

# promoters from each track
apps_pr = len(filter_data_df(apps, 'Rating', 'Promoter'))
games_pr = len(filter_data_df(games, 'Rating', 'Promoter'))
vr_pr = len(filter_data_df(vr, 'Rating', 'Promoter'))
intro_pr = len(filter_data_df(intro, 'Rating', 'Promoter'))
apps_4w_pr = len(filter_data_df(apps_4w, 'Rating', 'Promoter'))

track_prs = {'Track': ['Apps', 'Games', 'VR', 'Intro', 'Apps (4-Week)'], 
             'Promoters':[apps_pr, games_pr, vr_pr, intro_pr, apps_4w_pr], 
             'Total':[len(apps), len(games), len(vr), len(intro), len(apps_4w)]}
track_prs_df = pd.DataFrame(track_prs)
ax = track_prs_df.plot(kind='bar', title ="2016 Promoters From Each Track", rot=0, figsize=(15, 10))
ax.set_xticks(track_prs_df.index)
ax.set_xticklabels(track_prs_df.Track)
plt.xlabel('Track')
plt.ylabel("# of Promoters")
plt.ylim(0,500)
plt.show()

# %% [markdown]
# ### 2. Promoters from each location

# %%
complete_2016_df.Location.unique()

# %%
la = filter_data_df(complete_2016_df, 'Location', ' LA')
ny = filter_data_df(complete_2016_df, 'Location', ' NY')
sf = filter_data_df(complete_2016_df, 'Location', ' SF')
sg = filter_data_df(complete_2016_df, 'Location', ' SG')
sv = filter_data_df(complete_2016_df, 'Location', ' SV')
hk = filter_data_df(complete_2016_df, 'Location', ' HK')
tp = filter_data_df(complete_2016_df, 'Location', ' Taipei')
tk = filter_data_df(complete_2016_df, 'Location', ' Tokyo')

la_pr = len(filter_data_df(la, 'Rating', 'Promoter'))
ny_pr = len(filter_data_df(ny, 'Rating', 'Promoter'))
sf_pr = len(filter_data_df(sf, 'Rating', 'Promoter'))
sg_pr = len(filter_data_df(sg, 'Rating', 'Promoter'))
sv_pr = len(filter_data_df(sv, 'Rating', 'Promoter'))
hk_pr = len(filter_data_df(hk, 'Rating', 'Promoter'))
tp_pr = len(filter_data_df(tp, 'Rating', 'Promoter'))
tk_pr = len(filter_data_df(tk, 'Rating', 'Promoter'))

location_prs = {'Location': ['LA', 'NY', 'SF', 'SG', 'SV', 'HK', 'Taipei', 'Tokyo'], 
                'Promoters': [la_pr, ny_pr,sf_pr, sg_pr, sv_pr, hk_pr, tp_pr, tk_pr], 
                'Total':[len(la), len(ny), len(sf), len(sg), len(sv), len(hk), len(tp), len(tk)]}
loc_prs_df = pd.DataFrame(location_prs)
ax2 = loc_prs_df.plot(kind='bar', title ="2016 Promoters From Each Location", rot=0, figsize=(10, 5))
ax2.set_xticks(loc_prs_df.index)
ax2.set_xticklabels(loc_prs_df.Location)
plt.xlabel('Location')
plt.ylabel("# of Promoters")
plt.ylim(0,350)
plt.show()

# Why does SG have fewer percentage of promoters? Due to pace?

# %% [markdown]
# ### 3. Each Week's Average Pace

# %%
def get_avg_pace():
    avg_paces = []
    for i in range(1,8):
        df_week = complete_2016_df[complete_2016_df["Week"] == '%i' % i]
        df_p = df_week[df_week['Schedule Pacing'] != '#REF!']
        avg = df_p['Schedule Pacing'].mean()
        avg_paces = np.append(avg_paces, avg)
    return avg_paces

avg_data_2016 = {'Week': [i for i in range(1,8)], 'Average Pace': get_avg_pace()}
nps_df_2016 = pd.DataFrame(avg_data_2016)
nps_df_2016.plot(x="Week", y="Average Pace", title="Average Pace of Week 1-7 in 2016", figsize=(8, 5)) #W8 has no pacing
plt.xlim(1,7)
plt.ylim(1,5)
# Out:
# (1, 5)

# %% [markdown]
# ### 4.  Why does certain locations (SF, SV) have higher promoter rates than others (SG)?

# %%
sf_= filter_data_df(complete_2016_df, 'Location', ' SF')
sf_p = sf_['Schedule Pacing'].dropna(axis=0, how='all').mean()

sf_p

sg_ = filter_data_df(complete_2016_df, 'Location', ' SG')
sg_p = sg_['Schedule Pacing'].dropna(axis=0, how='all').mean()
sg_p
# Out:
# 3.3541666666666665

# %% [markdown]
# <h1>2017</h1>

# %%
df_2017 = pd.read_csv('datasets/2017/Student Feedback Surveys-Superview.csv')

# convert pacing value
df_2017['Schedule Pacing'] = df_2017['Schedule Pacing'].map({"Just right" : 3, 
                                                             "A little too fast" : 4, 
                                                             "A little too slow" : 2, 
                                                             "Way too slow" : 1, 
                                                             "Way too fast" : 5})
# convert week value
df_2017['Week'] = df_2017['Week'].map({"Week 1" : 1, 
                                       "Week 2" : 2,
                                       "Week 3" : 3,
                                       "Week 4" : 4,
                                       "Week 5" : 5,
                                       "Week 6" : 6,
                                       "Week 7" : 7,
                                       "Week 8" : 8})
year_17 = [ 2017 for i in range(len(df_2017))]
df_2017['Year'] = year_17



# convert rating to NPS segments


def convert_ratings(df, rating_name):
    ratings = df[rating_name]
    new_ratings = np.array([])
    for n in ratings:
        if not n == "nan" and not n == "#ERROR!":
            if float(n) > 8:
                new_ratings = np.append(new_ratings, "Promoter")
            elif float(n) > 6:
                new_ratings = np.append(new_ratings, "Passive")
            else:
                new_ratings = np.append(new_ratings, "Detractor")
        else:
            new_ratings = np.append(new_ratings, "NaN")
    return new_ratings

rating_df = pd.DataFrame(convert_ratings(df_2017, 'Rating (Num)'))
df_2017['Rating (Num)'] = rating_df
clean_df_2017 = df_2017.rename(columns={'Rating (Num)': 'Rating'})

clean_df_2017
# Out:
#         ID       Location            Track  Week     Rating  Schedule Pacing  \
# 0      134  San Francisco   Apps, Explorer     1  Detractor              3.0
# 1       36    Los Angeles             Apps     1  Detractor              4.0
# 2      117  San Francisco            Games     1  Detractor              1.0
# 3      253            NaN              NaN     2  Detractor              4.0
# 4      350  New York City   Apps, Explorer     1  Detractor              3.0
# 5       23   Redwood City             Apps     1  Detractor              3.0
# 6       28    Los Angeles             Apps     7  Detractor              3.0
# 7       65  San Francisco             Apps     1  Detractor              2.0
# 8      101    Santa Clara             Apps     1  Detractor              2.0
# 9      124    Santa Clara             Apps     1  Detractor              3.0
# 10     157   Redwood City             Apps     2  Detractor              3.0
# 11     170        Oakland             Apps     2  Detractor              3.0
# 12     255  San Francisco             Apps     2  Detractor              5.0
# 13     289  Washington DC             Apps     1  Detractor              3.0
# 14     299  Washington DC   Apps, Explorer     1  Detractor              2.0
# 15     307            NaN              NaN     3  Detractor              2.0
# 16     319   Redwood City             Apps     3  Detractor              3.0
# 17     336  New York City             Apps     1  Detractor              2.0
# 18     441  San Francisco   Apps, Explorer     3  Detractor              3.0
# 1443  2017
# 1444  2017
# 1445  2017
# 1446  2017
# 1447  2017
# 1448  2017
# 1449  2017
# 1450  2017
# 1451  2017
# 1452  2017
#
# [1453 rows x 7 columns]

# %%
def get_nps_2017():
    nps_scores = []
    for i in range(1,9):
        df_week = clean_df_2017[clean_df_2017["Week"] == i]
        promos = df_week[df_week["Rating"] == "Promoter"].size
        detracts = df_week[df_week["Rating"] == "Detractor"].size
        passives = df_week[df_week["Rating"] == "Passive"].size
        nps = (promos - detracts) / (promos + detracts + passives) * 100
        nps_scores = np.append(nps_scores, nps)
    return nps_scores

nps_2017 = get_nps_2017()
data_2017 = {'Week': [i for i in range(1,9)], 'NPS': nps_2017}
nps_df_2017 = pd.DataFrame(data_2017)
nps_df_2017.plot(x="Week", y="NPS", title="NPS of Each Week in 2017", figsize=(8, 5))
plt.xlim(1,8)
plt.ylim(-100,100)
# Out:
# (-100, 100)

# %% [markdown]
# ### 1. Promoters from Each Track

# %%
apps_17 = filter_data_df(clean_df_2017, 'Track', 'Apps')
games_17 = filter_data_df(clean_df_2017, 'Track', 'Games')
vr_17 = filter_data_df(clean_df_2017, 'Track', 'VR')
games_exp = filter_data_df(clean_df_2017, 'Track', 'Games, Explorer')
apps_exp = filter_data_df(clean_df_2017, 'Track', 'Apps, Explorer')

apps_17_pr = len(filter_data_df(apps_17, 'Rating', 'Promoter'))
games_17_pr = len(filter_data_df(games_17, 'Rating', 'Promoter'))
vr_17_pr = len(filter_data_df(vr_17, 'Rating', 'Promoter'))
games_exp_pr = len(filter_data_df(games_exp, 'Rating', 'Promoter'))
apps_exp_pr = len(filter_data_df(apps_exp, 'Rating', 'Promoter'))

track_prs_17 = {'Track': ['Apps', 'Games', 'VR', 'Games-Explorer', 'Apps-Explorer'], 
             'Promoters':[apps_17_pr, games_17_pr, vr_17_pr, games_exp_pr, apps_exp_pr], 
             'Total':[len(apps_17), len(games_17), len(vr_17), len(games_exp), len(apps_exp)]}
track_prs_17_df = pd.DataFrame(track_prs_17)
ax = track_prs_17_df.plot(kind='bar', title ="2017 Promoters From Each Track", rot=0, figsize=(15, 10))
ax.set_xticks(track_prs_17_df.index)
ax.set_xticklabels(track_prs_17_df.Track)
plt.xlabel('Track')
plt.ylabel("# of Promoters")
plt.ylim(0,900)
plt.show()

# %%
clean_df_2017.Location.unique()
# Out:
# array(['San Francisco', 'Los Angeles', nan, 'New York City',
#        'Redwood City', 'Santa Clara', 'Oakland', 'Washington DC',
#        'Chicago', 'Atlanta', 'Hong Kong', 'Beijing', 'Tokyo'], dtype=object)

# %% [markdown]
# #### Percentages - Promoters from each track 2016 & 2017

# %%
# 2017
app_p = apps_17_pr/len(apps_17) #50.29%
games_p = games_17_pr/len(games_17) #63.94%
vr_p = vr_17_pr/len(vr_17) #76.67%

# 2016
app_16 = apps_pr/len(apps) #37.91%
games_16 = games_pr/len(games) #45.55%
vr_16 = vr_pr/len(vr) # 45.45%

# %% [markdown]
# ### 2. Promoters from each location

# %%
la_17 = filter_data_df(clean_df_2017, 'Location', 'Los Angeles')
ny_17 = filter_data_df(clean_df_2017, 'Location', 'New York City')
sf_17 = filter_data_df(clean_df_2017, 'Location', 'San Francisco')
rc = filter_data_df(clean_df_2017, 'Location', 'Redwood City')
sc = filter_data_df(clean_df_2017, 'Location', 'Santa Clara')
dc = filter_data_df(clean_df_2017, 'Location', 'Washington DC')
ch = filter_data_df(clean_df_2017, 'Location', 'Chicago')
at = filter_data_df(clean_df_2017, 'Location', 'Atlanta')
hk_17 = filter_data_df(clean_df_2017, 'Location', 'Hong Kong')
bj = filter_data_df(clean_df_2017, 'Location', 'Beijing')
tk_17 = filter_data_df(clean_df_2017, 'Location', 'Tokyo')

la_17_pr = len(filter_data_df(la_17, 'Rating', 'Promoter'))
ny_17_pr = len(filter_data_df(ny_17, 'Rating', 'Promoter'))
sf_17_pr = len(filter_data_df(sf_17, 'Rating', 'Promoter'))
rc_pr = len(filter_data_df(rc, 'Rating', 'Promoter'))
sc_pr = len(filter_data_df(sc, 'Rating', 'Promoter'))
dc_pr = len(filter_data_df(dc, 'Rating', 'Promoter'))
ch_pr = len(filter_data_df(ch, 'Rating', 'Promoter'))
at_pr = len(filter_data_df(at, 'Rating', 'Promoter'))
hk_17_pr = len(filter_data_df(hk_17, 'Rating', 'Promoter'))
bj_pr = len(filter_data_df(bj, 'Rating', 'Promoter'))
tk_17_pr = len(filter_data_df(tk_17, 'Rating', 'Promoter'))

fig = plt.gcf()
fig.set_size_inches(200,200)

location_17_prs = {'Location': ['LA', 'NY', 'SF', 'RC','SC', 'DC', 'CH', 'AT','HK', 'BJ', 'TK'], 
                'Promoters': [la_17_pr, ny_17_pr, sf_17_pr, rc_pr, sc_pr, dc_pr,ch_pr, at_pr, hk_17_pr, bj_pr, tk_17_pr], 
                'Total':[len(la_17), len(ny_17), len(sf_17), len(rc), len(sc), len(dc), len(ch), len(at), len(hk_17), len(bj), len(tk_17)]}
loc_prs_17_df = pd.DataFrame(location_17_prs)
ax2 = loc_prs_17_df.plot(kind='bar', title ="2017 Promoters From Each Location", rot=0, figsize=(15, 10))
ax2.set_xticks(loc_prs_17_df.index)
ax2.set_xticklabels(loc_prs_17_df.Location)
plt.xlabel('Location')
plt.ylabel("# of Promoters")
plt.ylim(0,400)
plt.show()

# %% [markdown]
# ### 3. Each Week's Average Pace

# %%
def get_avg_pace_17():
    avg_paces = []
    for i in range(1,9):
        df_week = clean_df_2017[clean_df_2017["Week"] == i]
        avg = df_week['Schedule Pacing'].mean()
        avg_paces = np.append(avg_paces, avg)
    return avg_paces

avg_data_2017 = {'Week': [i for i in range(1,9)], 'Average Pace': get_avg_pace_17()}
nps_df_2017 = pd.DataFrame(avg_data_2017)
nps_df_2017.plot(x="Week", y="Average Pace", title="Average Pace of Each Week in 2017", figsize=(8, 5)) #W8 has no pacing
plt.xlim(1,8)
plt.ylim(1,5)
# Out:
# (1, 5)

# %% [markdown]
# <h1>Concatenation of 2016 & 2017 </h1>

# %%
frames_all = [complete_2016_df, clean_df_2017]
df_all = pd.concat(frames_all)
df_all
# Out:
